# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendaRibss/Estrutura_de_dados_II/blob/main/Exerc%C3%ADcio01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 01: Crie um programa que leia 10 números inteiros e armazene-os em um array.

vetor = [] #criando um vetor para armazenar os números
soma = 0

for i in range(10): #criando um for para gerar um loop de 10 números inseridos
    numero = int(input(f"Digite o {i + 1}º número: "))
    vetor.append(numero)
    soma += numero

media = soma / 10

print("\nNúmeros digitados:") #mostrando os números escolhidos
for numero in vetor:
    print(numero, end=" ")

print(f"\nSoma: {soma}") #mostrando as soma dos números inseridos
print(f"Média: {media:.2f}")
# Out:
# Digite o 1º número: 7
# Digite o 2º número: 8
# Digite o 3º número: 9
# Digite o 4º número: 4
# Digite o 5º número: 5
# Digite o 6º número: 6
# Digite o 7º número: 1
# Digite o 8º número: 2
# Digite o 9º número: 3
# Digite o 10º número: 7
#
# Números digitados:
# 7 8 9 4 5 6 1 2 3 7
# Soma: 52
# Média: 5.20
